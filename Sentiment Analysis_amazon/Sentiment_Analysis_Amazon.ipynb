# %% [markdown]
# ### Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# !ls
# Out:
# /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# amazon_alexa.tsv  amazon_f_handson.ipynb

# %% [markdown]
# ### Import Dataset

# %%
import pandas as pd

data = pd.read_csv('/content/amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import numpy as np

# Replace NaN values with empty strings
data_balanced['review'].fillna('', inplace=True)

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list
cleaned_reviews = [clean_text(review) for review in reviews]

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 8                                           looks great      1
# 10    I sent it to my 85 year old Dad, and he talks ...      1
# 12    I purchased this for my mother who is having k...      1
# 19    I liked the original Echo. This is the same bu...      1
# 28    Fun item to play with and get used to using.  ...      1
# ...                                                 ...    ...
# 3097                               I have a friend now.      1
# 3116            I enjoy it. Still discovering new uses.      1
# 3119  It's pretty fun and nice to have a speaker tha...      1
# 3138  Este producto llegó y a la semana se quedó sin...      1
# 3149                                               Good      1
#
#                                           clean_reviews
# 8                                           looks great
# 10    sent it to my 85 year old dad and he talks to ...
# 12    purchased this for my mother who is having kne...
# 19    liked the original echo this is the same but s...
# 28    fun item to play with and get used to using so...
# ...                                                 ...
# 3097                                    have friend now
# 3116                enjoy it still discovering new uses
# 3119  it pretty fun and nice to have speaker that re...
# 3138  este producto llegó la semana se quedó sin olo...
# 3149                                               good
#
# [514 rows x 3 columns]

# %% [markdown]
# ## Data Split

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.6/663.6 kB 12.9 MB/s eta 0:00:00

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# !pip install genai
# Out:
# Requirement already satisfied: genai in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: ipython<9.0.0,>=8.10.0 in /usr/local/lib/python3.10/dist-packages (from genai) (8.23.0)
# Requirement already satisfied: openai<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from genai) (0.27.10)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from genai) (0.9.0)
# Requirement already satisfied: tiktoken<0.4.0,>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from genai) (0.3.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (2.16.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (5.14.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (1.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (4.10.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython<9.0.0,>=8.10.0->genai) (4.9.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai<0.28.0,>=0.27.0->genai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai<0.28.0,>=0.27.0->genai) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai<0.28.0,>=0.27.0->genai) (3.9.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.4.0,>=0.3.2->genai) (2023.12.25)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython<9.0.0,>=8.10.0->genai) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython<9.0.0,>=8.10.0->genai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9.0.0,>=8.10.0->genai) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.28.0,>=0.27.0->genai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.28.0,>=0.27.0->genai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.28.0,>=0.27.0->genai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<0.28.0,>=0.27.0->genai) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (4.0.3)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython<9.0.0,>=8.10.0->genai) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython<9.0.0,>=8.10.0->genai) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython<9.0.0,>=8.10.0->genai) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython<9.0.0,>=8.10.0->genai) (1.16.0)

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 50.4 ms, sys: 9.2 ms, total: 59.6 ms
# Wall time: 7.65 s
# > The meaning of life is a subject that has been puzzled by philosophers, religious leaders, and individuals throughout history. Over time, various perspectives emerged:
# >
# > **1. Objective Meaning:**
# >
# > * Some believe that life has an inherent objective meaning or purpose given by a higher power or the universe, such as:
# >     * Fulfilling a divine plan or destiny
# >     * Contributing to the greater good of humanity
# >     * Advancing knowledge and progress
# >
# > **2. Subjective Meaning:**
# >
# > * Others assert that the meaning of life is subjective and depends on the individual. It can be found through:
# >     * Personal values, passions, and goals
# >     * Relationships with others
# >     * Experiences and accomplishments that bring fulfillment
# >
# > **3. Existential Viewpoints:**
# >
# > * Existentialists emphasize the absurdity of life and the responsibility of individuals to create their own meaning.
# >     * Absurdism: Recognizes the inherent meaninglessness but advocates for embracing life's contradictions and seeking purpose in spite of them.
# >     * Existentialism: Stresses personal freedom, authenticity, and responsibility for defining one's own existence.
# >
# > **4. Scientific Theories:**
# >
# > * Some scientific theories propose that life is:
# >     * A product of random evolution, without inherent meaning
# >     * A complex system that emerged through natural selection, driven by the desire to survive and reproduce
# >     * A self-organized process that seeks order and complexity
# >
# > **5. Cultural and Social Factors:**
# >
# > * Cultural and societal norms play a significant role in shaping our understanding of the meaning of life.
# >     * Traditions, beliefs, and values can provide individuals with a framework for finding purpose and direction.
# >     * Social interactions and community engagement can also contribute to a sense of belonging and purpose.
# >
# > **Personal Perspectives:**
# >
# > Ultimately, the meaning of life is a deeply personal question. There is no single, universally agreed-upon answer. It is a journey of self-discovery, exploration, and reflection. Through experiences, relationships, and a search for purpose, individuals can find meaning that is both unique and fulfilling to them.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 524                                                          0
# 2183                                     awesome device      1
# 2964  Ask it to play Motown radio on Pandora and it ...      0
# 787                               Good sound works well      1
# 29                              Just like the other one      1
# 1173                                        Love these!      1
# 2975  Been debating on getting one, but am happy I d...      1
# 741   It's like Siri, in fact, Siri answers more acc...      0
# 1112                                                         0
# 3097                               I have a friend now.      1
# 2439  Seems to work ok, but no youtube tv?  Really? ...      0
# 2035  Alexa is the best smart speaker out there I'm ...      1
# 2909  For the price, the product is nice quality and...      0
# 1228              I used it as an alarm clock  i lov it      1
# 566   The second one which was a refurbished model d...      0
# 504   There was something wrong with the first one t...      0
# 562   Bought 2 and both quit connecting to wifi and ...      0
# 2162  Was loving it but starting in June Hulu stoppe...      0
# 579   great product, but useless overall. Too many u...      0
# 12    I purchased this for my mother who is having k...      1
#
#                                           clean_reviews pred_label
# 524
# 2183                                     awesome device
# 2964  ask it to play motown radio on pandora and it ...
# 787                               good sound works well
# 29                              just like the other one
# 1173                                         love these
# 2975  been debating on getting one but am happy did ...
# 741   it like siri in fact siri answers more accurat...
# 1112
# 3097                                    have friend now
# 2439  seems to work ok but no youtube tv really can ...
# 2035  alexa is the best smart speaker out there so g...
# 2909  for the price the product is nice quality and ...
# 1228                   used it as an alarm clock lov it
# 566   the second one which was refurbished model did...
# 504   there was something wrong with the first one t...
# 562   bought 2 and both quit connecting to wifi and ...
# 2162  was loving it but starting in june hulu stoppe...
# 579   great product but useless overall too many unn...
# 12    purchased this for my mother who is having kne...

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"","pred_label":""},{"clean_reviews":"awesome device","pred_label":""},{"clean_reviews":"ask it to play motown radio on pandora and it keeps asking if want to add salsa station motown isn close to salsa phonetically","pred_label":""},{"clean_reviews":"good sound works well","pred_label":""},{"clean_reviews":"just like the other one","pred_label":""},{"clean_reviews":"love these","pred_label":""},{"clean_reviews":"been debating on getting one but am happy did still more to explore thanks","pred_label":""},{"clean_reviews":"it like siri in fact siri answers more accurately then alexa don see real need for it in my household though it was good bargain on prime day deals","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have friend now","pred_label":""},{"clean_reviews":"seems to work ok but no youtube tv really can believe they would ban an app that so many people want to use really wanted to like it but when couldn install that particular app it became almost useless almost does most other stuff just fine but ll stick with my roku","pred_label":""},{"clean_reviews":"alexa is the best smart speaker out there so glad came across it the sound is so amazing and mostly use amazon alexa for music and school work help love to control my room lights and the color totally recommend","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"used it as an alarm clock lov it","pred_label":""},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":""},{"clean_reviews":"there was something wrong with the first one that no even the rep spoke with could fix the replacement was registered to someone else when the price of the dot went down to 39 99 same price as the refurbished ones bought brand spanking new one no problem with the new one","pred_label":""},{"clean_reviews":"bought 2 and both quit connecting to wifi and responding to voice within 9 months hard and soft reset will not fix the problem","pred_label":""},{"clean_reviews":"was loving it but starting in june hulu stopped working and crunchyroll doesn work either probably will switch to something else soon","pred_label":""},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":""},{"clean_reviews":"purchased this for my mother who is having knee problems now to give her something to do while trying to over come not getting around so fast like she did she enjoys all the little and big things it can do alexa play this song what time is it and where and how to cook this and that","pred_label":""}]

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"","pred_label":""},{"clean_reviews":"awesome device","pred_label":""},{"clean_reviews":"ask it to play motown radio on pandora and it keeps asking if want to add salsa station motown isn close to salsa phonetically","pred_label":""},{"clean_reviews":"good sound works well","pred_label":""},{"clean_reviews":"just like the other one","pred_label":""},{"clean_reviews":"love these","pred_label":""},{"clean_reviews":"been debating on getting one but am happy did still more to explore thanks","pred_label":""},{"clean_reviews":"it like siri in fact siri answers more accurately then alexa don see real need for it in my household though it was good bargain on prime day deals","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have friend now","pred_label":""},{"clean_reviews":"seems to work ok but no youtube tv really can believe they would ban an app that so many people want to use really wanted to like it but when couldn install that particular app it became almost useless almost does most other stuff just fine but ll stick with my roku","pred_label":""},{"clean_reviews":"alexa is the best smart speaker out there so glad came across it the sound is so amazing and mostly use amazon alexa for music and school work help love to control my room lights and the color totally recommend","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"used it as an alarm clock lov it","pred_label":""},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":""},{"clean_reviews":"there was something wrong with the first one that no even the rep spoke with could fix the replacement was registered to someone else when the price of the dot went down to 39 99 same price as the refurbished ones bought brand spanking new one no problem with the new one","pred_label":""},{"clean_reviews":"bought 2 and both quit connecting to wifi and responding to voice within 9 months hard and soft reset will not fix the problem","pred_label":""},{"clean_reviews":"was loving it but starting in june hulu stopped working and crunchyroll doesn work either probably will switch to something else soon","pred_label":""},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":""},{"clean_reviews":"purchased this for my mother who is having knee problems now to give her something to do while trying to over come not getting around so fast like she did she enjoys all the little and big things it can do alexa play this song what time is it and where and how to cook this and that","pred_label":""}]
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"","pred_label":1},{"clean_reviews":"awesome device","pred_label":1},{"clean_reviews":"ask it to play motown radio on pandora and it keeps asking if want to add salsa station motown isn close to salsa phonetically","pred_label":0},{"clean_reviews":"good sound works well","pred_label":1},{"clean_reviews":"just like the other one","pred_label":1},{"clean_reviews":"love these","pred_label":1},{"clean_reviews":"been debating on getting one but am happy did still more to explore thanks","pred_label":1},{"clean_reviews":"it like siri in fact siri answers more accurately then alexa don see real need for it in my household though it was good bargain on prime day deals","pred_label":0},{"clean_reviews":"","pred_label":1},{"clean_reviews":"have friend now","pred_label":1},{"clean_reviews":"seems to work ok but no youtube tv really can believe they would ban an app that so many people want to use really wanted to like it but when couldn install that particular app it became almost useless almost does most other stuff just fine but ll stick with my roku","pred_label":0},{"clean_reviews":"alexa is the best smart speaker out there so glad came across it the sound is so amazing and mostly use amazon alexa for music and school work help love to control my room lights and the color totally recommend","pred_label":1},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":0},{"clean_reviews":"used it as an alarm clock lov it","pred_label":1},{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":0},{"clean_reviews":"there was something wrong with the first one that no even the rep spoke with could fix the replacement was registered to someone else when the price of the dot went down to 39 99 same price as the refurbished ones bought brand spanking new one no problem with the new one","pred_label":0},{"clean_reviews":"bought 2 and both quit connecting to wifi and responding to voice within 9 months hard and soft reset will not fix the problem","pred_label":0},{"clean_reviews":"was loving it but starting in june hulu stopped working and crunchyroll doesn work either probably will switch to something else soon","pred_label":0},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":0},{"clean_reviews":"purchased this for my mother who is having knee problems now to give her something to do while trying to over come not getting around so fast like she did she enjoys all the little and big things it can do alexa play this song what time is it and where and how to cook this and that","pred_label":1}]
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0                                                               1
# 1                                      awesome device           1
# 2   ask it to play motown radio on pandora and it ...           0
# 3                               good sound works well           1
# 4                             just like the other one           1
# 5                                          love these           1
# 6   been debating on getting one but am happy did ...           1
# 7   it like siri in fact siri answers more accurat...           0
# 8                                                               1
# 9                                     have friend now           1
# 10  seems to work ok but no youtube tv really can ...           0
# 11  alexa is the best smart speaker out there so g...           1
# 12  for the price the product is nice quality and ...           0
# 13                   used it as an alarm clock lov it           1
# 14  the second one which was refurbished model did...           0
# 15  there was something wrong with the first one t...           0
# 16  bought 2 and both quit connecting to wifi and ...           0
# 17  was loving it but starting in june hulu stoppe...           0
# 18  great product but useless overall too many unn...           0
# 19  purchased this for my mother who is having kne...           1

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 524                                                          0
# 2183                                     awesome device      1
# 2964  Ask it to play Motown radio on Pandora and it ...      0
# 787                               Good sound works well      1
# 29                              Just like the other one      1
# 1173                                        Love these!      1
# 2975  Been debating on getting one, but am happy I d...      1
# 741   It's like Siri, in fact, Siri answers more acc...      0
# 1112                                                         0
# 3097                               I have a friend now.      1
# 2439  Seems to work ok, but no youtube tv?  Really? ...      0
# 2035  Alexa is the best smart speaker out there I'm ...      1
# 2909  For the price, the product is nice quality and...      0
# 1228              I used it as an alarm clock  i lov it      1
# 566   The second one which was a refurbished model d...      0
# 504   There was something wrong with the first one t...      0
# 562   Bought 2 and both quit connecting to wifi and ...      0
# 2162  Was loving it but starting in June Hulu stoppe...      0
# 579   great product, but useless overall. Too many u...      0
# 12    I purchased this for my mother who is having k...      1
#
#                                           clean_reviews  pred_label
# 524                                                               1
# 2183                                     awesome device           1
# 2964  ask it to play motown radio on pandora and it ...           0
# 787                               good sound works well           1
# 29                              just like the other one           1
# 1173                                         love these           1
# 2975  been debating on getting one but am happy did ...           1
# 741   it like siri in fact siri answers more accurat...           0
# 1112                                                              1
# 3097                                    have friend now           1
# 2439  seems to work ok but no youtube tv really can ...           0
# 2035  alexa is the best smart speaker out there so g...           1
# 2909  for the price the product is nice quality and ...           0
# 1228                   used it as an alarm clock lov it           1
# 566   the second one which was refurbished model did...           0
# 504   there was something wrong with the first one t...           0
# 562   bought 2 and both quit connecting to wifi and ...           0
# 2162  was loving it but starting in june hulu stoppe...           0
# 579   great product but useless overall too many unn...           0
# 12    purchased this for my mother who is having kne...           1

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[9, 2],
#        [0, 9]])

# %% [markdown]
# ### OpenAI API Config

# %%
# !pip install openai==0.27.0
# Out:
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.10
#     Uninstalling openai-0.27.10:
#       Successfully uninstalled openai-0.27.10
# Successfully installed openai-0.27.0

# %%
import openai
from google.colab import userdata

OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')
openai.api_key  = OPENAI_API_KEY

# %%
def get_completion(prompt, model="gpt-3.5-turbo-1106"):

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)

  return response.choices[0].message["content"]

# %%
prompt = "Why is the sky blue?"

chatgpt_response = get_completion(prompt)

# %%
chatgpt_response
# Out:
# "The sky appears blue to our eyes because of the way the Earth's atmosphere scatters sunlight. The molecules in the Earth's atmosphere, particularly nitrogen and oxygen, scatter shorter wavelengths of light (blue and violet) more effectively than longer wavelengths (red and yellow). This scattering causes the blue light to be more visible to us, giving the sky its blue color."

# %% [markdown]
# #### Batching API Calls (Single Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 1080                           I love my new Echo Spot!      1
# 368   I returned 2 Echo Dots & am only getting refun...      0
# 3097                               I have a friend now.      1
# 2643                 Good speaker for bedroom or office      1
# 2196           I love the Alexa remote and easy to use.      1
# ...                                                 ...    ...
# 2576                                   Work pretty well      1
# 3027  Works great.Having fun playing music,checking ...      1
# 2383  Garbage...Even trying to watch Amazon Prime Vi...      0
# 376   Doesn't always respond when spoken to with pro...      0
# 2737  Dislike the volume. It does not sound loud eno...      1
#
#                                           clean_reviews pred_label
# 1080                              love my new echo spot
# 368   returned 2 echo dots am only getting refund fo...
# 3097                                    have friend now
# 2643                 good speaker for bedroom or office
# 2196              love the alexa remote and easy to use
# ...                                                 ...        ...
# 2576                                   work pretty well
# 3027  works great having fun playing music checking ...
# 2383  garbage even trying to watch amazon prime vide...
# 376   doesn always respond when spoken to with promp...
# 2737   dislike the volume it does not sound loud enough
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"love my new echo spot","pred_label":""},{"clean_reviews":"returned 2 echo dots am only getting refund for 1 returned 2 in one package want my refunds for both of them they are in the same package can you not see them both","pred_label":""},{"clean_reviews":"have friend now","pred_label":""},{"clean_reviews":"good speaker for bedroom or office","pred_label":""},{"clean_reviews":"love the alexa remote and easy to use","pred_label":""},{"clean_reviews":"purchased this refurbished works just like brand new 3 minute set up very easy now have echo dot that can command to start playing music for my backyard deck sound system","pred_label":""},{"clean_reviews":"works great as bt receiver with output connected to vintage stereo equipment","pred_label":""},{"clean_reviews":"see subject line love it","pred_label":""},{"clean_reviews":"had dot and upgraded to this like it my only complaint is the very short instructions","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"love everything about this product bought two one for my household and one for my mother in law just so we can video chat with her and for emergency and it easy to use for older folks","pred_label":""},{"clean_reviews":"have had for just one week so far and can say it is blast to have","pred_label":""},{"clean_reviews":"we love the fire tv stick and will love it even more when we sever our cable connection when our service agreement expires","pred_label":""},{"clean_reviews":"don like that it goes into sleep mode after 20 30 minutes of inactivity shouldn have to wake up the fire tv to finish watching show","pred_label":""},{"clean_reviews":"great easy to set up little difficult to navigate and the instructions are non existent","pred_label":""},{"clean_reviews":"used it as an alarm clock lov it","pred_label":""},{"clean_reviews":"wanted to use it as clock in our bedroom but the font is too small to see from any distance and apparently you can change it","pred_label":""},{"clean_reviews":"echo dot responds to us when we aren even talking to it ve unplugged it it feels like it 34 spying 34 on us","pred_label":""},{"clean_reviews":"used twice not working","pred_label":""},{"clean_reviews":"sure the echo is as cool as everyone says but won get to try this one even though have large covered porch the package was left on my top step on day forecast for 100 chance of rain and rain it did soaking the package not even going to open it and see how bad the damage is this order has been cursed from the beginning ordered as birthday gift and delivery was not made on scheduled day now get it and its rain soaked","pred_label":""},{"clean_reviews":"works great bought it for my shop so that it is like an intercom to the house","pred_label":""},{"clean_reviews":"easy set up","pred_label":""},{"clean_reviews":"very easy to install voice control is great","pred_label":""},{"clean_reviews":"it worked for month or so then it stopped ve tried everything to try and make it work but nothing is working want refund","pred_label":""},{"clean_reviews":"this is my second one have one in the kitchen and wanted another in my home office it is amazing for quick look up while am working live very busy life and it helps keep me on track with work and personal appointments will buy for holiday gifts for my whole family the gift of organization and information at voice command away","pred_label":""},{"clean_reviews":"almost as good as my bose love the whole house music","pred_label":""},{"clean_reviews":"we re thoroughly enjoying our amazon echo installation was easy using the alexa app purchased 2 kasa smart plugs to control our living room lights installation again was easy using the kasa app they sinqued right up with the echo we re enjoying playing music with the echo and the sound quality is awesome we ve added kasa smart bulb for our kitchen setup was seamless we re looking forward to adding more automation to our home","pred_label":""},{"clean_reviews":"stoppe ...
#   ```
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"not connected to my phone playlist","pred_label":""},{"clean_reviews":"the sound is amazing and many collections of all music","pred_label":""},{"clean_reviews":"like that she has the ability to do multiple different things like create to do list set and alarm play any song can think of and much more wish the sound could be tad louder","pred_label":""},{"clean_reviews":"brought to replace one that moved and doesn have the same range as my previous non refurbished unit it would seldom be able to find the wi fi and couldn connect got tired of hearing the message 34 trouble connecting check the alexa app 34 and just unplugged it went through the troubleshooting and reconnected it several times it just not as strong","pred_label":""},{"clean_reviews":"great buy","pred_label":""},{"clean_reviews":"exactly what wanted with speedy shipping thank you so much","pred_label":""},{"clean_reviews":"very easy setup","pred_label":""},{"clean_reviews":"why do we need to buy 100 hub to get it to work with samsung tv and many other devices want my money back this thing won even turn on my tv unless buy another hub what the point of having hub that doesn support half the devices out there don buy this thing unless you want to spend another 100 on another hub it won work with many of your devices just by the echo or dot if you must but not this better yet get google device they actually understand you when you talk","pred_label":""},{"clean_reviews":"sound is terrible cannot pair with echo to play simultaneously must upgrade to amazon music if you want to play more than one device at time","pred_label":""},{"clean_reviews":"cant figure out how to use it","pred_label":""},{"clean_reviews":"oh love my echo show and the video news spots","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"it not as good as siri but it still has some positives it great at playing music and setting alarms personally felt that paid too much for this product as it was nearly half off on prime day literally the day after purchased it so pretty disappointed might still return it and get my money back","pred_label":""},{"clean_reviews":"got to love alexa she does everything around our house","pred_label":""},{"clean_reviews":"easy to install up and running in minutes","pred_label":""},{"clean_reviews":"funny how you buy something just because it looks fun and it winds up being totally useful part of your home loving it","pred_label":""},{"clean_reviews":"use it primarily to play music it works wonderfully still getting used to some of the many things it will do amazon has sent several tips since got it thanks for all your help","pred_label":""},{"clean_reviews":"it pretty fun and nice to have speaker that responds to my questions but doesn understand my commands some of the time","pred_label":""},{"clean_reviews":"very nice and its does not take up space","pred_label":""},{"clean_reviews":"diversity so many things to see and hear wealth of information","pred_label":""},{"clean_reviews":"jumped on the bandwagon by purchasing an echo feel like there was struggle getting connected and then three days later the device is sharing news and weather now we use it some but have not tapped in to all options still testing it out","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this echo dot is horrible the volume on my phone is louder than than this device my boss has one at this is not the case","pred_label":""},{"clean_reviews":"easy to use easy to set up","pred_label":""},{"clean_reviews":"am quite disappointed by this product there clearly is bug half of the time ask for newsflash two second after it starts the whole thing stops and reboots for couple of minutes same goes when ask to play the radio also many times it get confused when ask to switch of 34 the lights 34 as other items are also named the same which is not true clearly no ai or natural language very beta stage still for me not impressed","pred_la ...
#   ```

# %%
import json
import pandas as pd

# Initialize an empty list to store DataFrame objects
dfs = []

for response in responses:
    # Clean the data by stripping the backticks
    json_data = response.strip("`")

    # Load the cleaned data
    data = json.loads(json_data)

    # Convert to DataFrame
    df_temp = pd.DataFrame(data)

    # Append the DataFrame to the list
    dfs.append(df_temp)

# Concatenate all DataFrames in the list into a single DataFrame
df_total = pd.concat(dfs, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0                               love my new echo spot           1
# 1   returned 2 echo dots am only getting refund fo...           0
# 2                                     have friend now           1
# 3                  good speaker for bedroom or office           1
# 4               love the alexa remote and easy to use           1
# ..                                                ...         ...
# 95                                   work pretty well           1
# 96  works great having fun playing music checking ...           1
# 97  garbage even trying to watch amazon prime vide...           0
# 98  doesn always respond when spoken to with promp...           0
# 99   dislike the volume it does not sound loud enough           0
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 1080                           I love my new Echo Spot!      1
# 368   I returned 2 Echo Dots & am only getting refun...      0
# 3097                               I have a friend now.      1
# 2643                 Good speaker for bedroom or office      1
# 2196           I love the Alexa remote and easy to use.      1
# ...                                                 ...    ...
# 2576                                   Work pretty well      1
# 3027  Works great.Having fun playing music,checking ...      1
# 2383  Garbage...Even trying to watch Amazon Prime Vi...      0
# 376   Doesn't always respond when spoken to with pro...      0
# 2737  Dislike the volume. It does not sound loud eno...      1
#
#                                           clean_reviews  pred_label
# 1080                              love my new echo spot           1
# 368   returned 2 echo dots am only getting refund fo...           0
# 3097                                    have friend now           1
# 2643                 good speaker for bedroom or office           1
# 2196              love the alexa remote and easy to use           1
# ...                                                 ...         ...
# 2576                                   work pretty well           1
# 3027  works great having fun playing music checking ...           1
# 2383  garbage even trying to watch amazon prime vide...           0
# 376   doesn always respond when spoken to with promp...           0
# 2737   dislike the volume it does not sound loud enough           0
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[41  0]
#  [ 6 53]]
#
# Accuracy: 0.94

# %% [markdown]
# ### Batching API Calls: Gemini API

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2929  We really love our Echo Dot, we can get questi...      1
# 436   Have now used for several months without problem.      1
# 350   Item no longer works after just 5 months of us...      0
# 493   Works good. However, the price went down the w...      1
# 3036  Easy to set up and does everything it’s a post...      1
# ...                                                 ...    ...
# 1899  It is as if we are having a conversation with ...      1
# 1225  You need a Harvard law degree to operate this ...      0
# 1104  As an Alexa device, it works just as well as a...      0
# 1406                                          Very good      1
# 668   It's ok. The speaker is pretty terrible. Googl...      0
#
#                                           clean_reviews pred_label
# 2929  we really love our echo dot we can get questio...
# 436    have now used for several months without problem
# 350   item no longer works after just 5 months of us...
# 493   works good however the price went down the wee...
# 3036  easy to set up and does everything it poster d...
# ...                                                 ...        ...
# 1899  it is as if we are having conversation with an...
# 1225  you need harvard law degree to operate this th...
# 1104  as an alexa device it works just as well as an...
# 1406                                          very good
# 668   it ok the speaker is pretty terrible google ho...
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 25

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gemini_completion_function(batch,current_batch,total_batch):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling Gemini API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)
  response = model.generate_content(prompt)
  time.sleep(5)

  return response

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gemini_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"we really love our echo dot we can get questions answered right away and play any music we can think of","pred_label":""},{"clean_reviews":"have now used for several months without problem","pred_label":""},{"clean_reviews":"item no longer works after just 5 months of use will not connect to wifi and unresponsive to reset requests","pred_label":""},{"clean_reviews":"works good however the price went down the week after purchased it","pred_label":""},{"clean_reviews":"easy to set up and does everything it poster despite its small size the speakers are adequate understands instructions from across the room very happy with the purchase","pred_label":""},{"clean_reviews":"would like to tell you that have reason to hate it like the speakers suck or the color or the shape or even the way it smells but can honestly say the number reason hate this device is have tried to set it up 3x now to no avail have 4 other echo devices already that set up and use quite regularly have reset my phone galaxy s8 checked the app for updates have cycled power to the echo unit with each attempt work in the network technology industry for living and have for over 20 years now so lack of experience or knowledge is not the problem here used the app and the device even tells me it is connected and to follow the app to continue set up the set up screen just continues to roll the 3 dots around the screen for about 5 minutes before the app locks up on my phone and have to force the app to close restart my phone and the echo and try again figured 3x was enough it shouldn be that hard techie can only imagine how bad this will prove to be for people whom have no clue about technology hope they won call me ll tell em to send the product back","pred_label":""},{"clean_reviews":"am not super impressed with alexa when my prime lapsed she wouldn play anything she isn smart enough to differentiate among spotify accounts so we can use it for that either she randomly speaks up when nobody is talking to her just today unplugged her not sure ll ever use my alexa again","pred_label":""},{"clean_reviews":"pretty cool have only begun to figure out things she does","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"sound is terrible cannot pair with echo to play simultaneously must upgrade to amazon music if you want to play more than one device at time","pred_label":""},{"clean_reviews":"this echo spot is great love it","pred_label":""},{"clean_reviews":"wanted to use these as radio and intercom as we get terrible fm reception where live the speech recognition software is horrible my wife and both are native americans whose language is english she is from the north am from texas neither have an accent from our birth area and yet it does not do good job understanding us we bought two they do the same thing additionally wifi reception was poor to marginal had to buy wifi range extender for office and the other is ten feet from our router both had problems switched them around no difference so it they are now disconnected dust collectors","pred_label":""},{"clean_reviews":"it is great tool helping with information","pred_label":""},{"clean_reviews":"an echo fan but this one did not work","pred_label":""},{"clean_reviews":"t ...
#   ```
#
# Now processing batch#: 2 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"had some trouble with my echo dot when first got it because of internet connection issues after doing research online saw from some other people that they had trouble with the 2nd generation echo dot however the same weekend took trip and brought my echo dot along to the hotel where it seemed to work just fine now back home the internet connection has seemed to have gotten through it little rough patch and haven had any problems since so if you are having connection issues with an echo dot then it is probably the internet and not the device","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"great","pred_label":""},{"clean_reviews":"great product but returning for new alexa dot refurbished is already giving me problems with connection","pred_label":""},{"clean_reviews":"purchased to use on the road in my semi does not work in that application","pred_label":""},{"clean_reviews":"wish bought one for work too","pred_label":""},{"clean_reviews":"it worked for month or so then it stopped ve tried everything to try and make it work but nothing is working want refund","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"like to use it for listening to podcasts like to set up the greeting in the morning to tell me what new the one thing don like was getting it to recognize the radio station wanted to listen to finally got it working but had to work through the bugs","pred_label":""},{"clean_reviews":"invasive and scared the crap out of me for speaking when it was not spoken to creapy af","pred_label":""},{"clean_reviews":"love my echo dot has many features and works great the only thing don like about it is that can play my imusic on it going to have to pay for spotify or amazon music account","pred_label":""},{"clean_reviews":"this is my second one have one in the kitchen and wanted another in my home office it is amazing for quick look up while am working live very busy life and it helps keep me on track with work and personal appointments will buy for holiday gifts for my whole family the gift of organization and information at voice command away","pred_label":""},{"clean_reviews":"no you tube wouldn have bought it if known that","pred_label":""},{"clean_reviews":"bought this to compare the speaker quality to our first generation speaker and like the sound better will ship this to my daughter though because like the fact that my first generation has chargeable base that we bought which keeps it more mobile and she needs better sound than what she has now","pred_label":""},{"clean_reviews":"would love this but there is no way to stop the screen from constantly scrolling through things to try if amazon would make this setting would change my review to 5 stars","pred_label":""},{"clean_reviews":"everything about it is great love the alexa voice remote","pred_label":""},{"clean_reviews":"this is my first alexa enabled device and so far its lived up to its reputation","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"we have used for last 2 weeks we like it my children also like it alexa has become part of our family","pred_label":""},{"clean_reviews":"love it was worried about the refurbished part at first but this being my first echo it is awesome have used it for everything my lights since work nights and shopping as well as for my spotify and planning on getting it for my parents to help them out for everyday things we take for granted when we are young would recommend this to everyone","pred_label":""},{"clean_reviews":"love the echo dot it amaxing","pred_label":""},{"clean_r ...
#   ```
#
# Now processing batch#: 3 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"the second one which was refurbished model did work at least not in my home","pred_label":""},{"clean_reviews":"just like the other one","pred_label":""},{"clean_reviews":"honestly it no different from the echo dots already own other then occasionally seeing the lyrics to song listening too really don see the difference","pred_label":""},{"clean_reviews":"the sound quality is not that good especially for the price that you pay for this would recommend to get the echo dot and buy better speaker instead maybe sonos and use the echo dot","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"love my new echo spot","pred_label":""},{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"it isn bad for what it is have issues with it actually playing what want getting it use iheartradio properly by playing the station want is challenge but it not bad for the sale price paid","pred_label":""},{"clean_reviews":"like the echo but not sure about the dot use it lot for music and audio books the sound quality of this smaller echo is nowhere near the quality of the full sized model haven decided if ll keep it or not","pred_label":""},{"clean_reviews":"very nice and its does not take up space","pred_label":""},{"clean_reviews":"not bad bad speaker for sound","pred_label":""},{"clean_reviews":"was excited to try this on my new element tv unfortunately even though my tv is 5 feet away from my router get maddening disconnections and buffering thought this little device was supposed to take care of that issue it didn","pred_label":""},{"clean_reviews":"have been thinking about getting this for long time and was excited when it arrived bundled with philip hue bulb the excited ended quickly spend about total of 4 hours attempting to add this bulb to my alexa echo plus everything tried ended in discovery failed message tried to set this up over and over and over again watched youtube videos read set up websites was the poster child of insanity doing the same thing over and over again and expecting different results the next day went onto amazon to get the tech support was hoping something would be done to make this thing work but also the problem not being operator error well after 3 tech support staff and 1 hr and 19 mins of being on the phone it still didn work this product has tested my patience so far this experience is shifting my mindset from going to smart home to just kicking it old school the only reason gave this two stars is because amazon will be sending me different echo plus and light bulb the problem wasn the bulb because before packing up the items purchased another bulb and still alexa couldn locate this device pray the next attempt is successful and then will revise this rating but what are the odds that was shipped defective echo the support person had the same thought maybe should be exploring the google device but can get over the look of that hub it looks like defuser can believe didn find youtube videos that show the problems did everything looked simple and seamless not the experience had ok done with this review because spend enough wasted time this weekend already","pred_label":""},{"clean_reviews":"still learning all the capabilities but so far pretty pretty pretty good","pred_label":""},{"clean_reviews":"fun item to play with and get used to using sometimes has hard time answering the questions you ask but think it will be better","pred_label":""},{"clean_reviews":"love it makes the simple things in life simpler","pred_label":""},{"clean_reviews":"like to use it for listening to podcasts like to set up the greeting in the morning to tell me what new the one thing don like was getting it to recognize the radio station wanted to listen to finally got it working but had to work through the bugs","pred_label":""},{"clean_reviews":"will never buy anything amazon makes again this fire stick is not even year old and it does nothing but restart and freeze up cons ...
#   ```
#
# Now processing batch#: 4 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"does not work all the time","pred_label":""},{"clean_reviews":"this is very user friendly","pred_label":""},{"clean_reviews":"it is very slow compared to the echo","pred_label":""},{"clean_reviews":"thought it would be more powerful and have lot more functionality not much better than the echo dot not worth the money","pred_label":""},{"clean_reviews":"this was an impulse buy but turns out really enjoy my new dot my grands love requesting songs and playing games like listening to my audible selection keeping up with my to do lists and discovering new alexa skills fun and practical my echo dot has been surprisingly welcome addition to my home","pred_label":""},{"clean_reviews":"have had for just one week so far and can say it is blast to have","pred_label":""},{"clean_reviews":"wish it had battery or was described better as plug in only item","pred_label":""},{"clean_reviews":"it was little hard to follow their instructions great product","pred_label":""},{"clean_reviews":"for as awesome as the echo and echo dots are the spot is disappointment there is very little control over what the screen shows what the clock looks like what order things show up in etc at this point if hadn thrown the box away immediately would have sent it back and just got another full size echo","pred_label":""},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":""},{"clean_reviews":"este producto lleg\u00f3 la semana se qued\u00f3 sin olor perdi\u00f3 toda su escencia huele solo alcohol","pred_label":""},{"clean_reviews":"up dated news","pred_label":""},{"clean_reviews":"brought to replace one that moved and doesn have the same range as my previous non refurbished unit it would seldom be able to find the wi fi and couldn connect got tired of hearing the message 34 trouble connecting check the alexa app 34 and just unplugged it went through the troubleshooting and reconnected it several times it just not as strong","pred_label":""},{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":""},{"clean_reviews":"do not understand all the excitement over these alexa devices or the google ones either it rarely gets what say correct does not control the dish receiver yes set it up correctly using the alexa app on my phone we got this for 129 which is good deal ti is definately not worth the 229 price though maybe in another month it will get better or either have one that is just deaf and dumb really can not recommend this item at the current time","pred_label":""},{"clean_reviews":"sound is terrible if want good music too get bose","pred_label":""},{"clean_reviews":"great addition to my echo plus","pred_label":""},{"clean_reviews":"the echo works fine but then you get indundated with 34 things to try 34 am not 10 year old that needs stimulus to tell me to do things found there is no way to turn this off except for turning off the screen if cannot find suitable fix for this it goes back","pred_label":""},{"clean_reviews":"awesome","pred_label":""},{"clean_reviews":"love the alexa remote and easy to use","pred_label":""},{"clean_reviews":"it is as if we are having conversation with another person instantaneous response and the fact that it catches your command even when you re far from it is simply just amazing","pred_label":""},{"clean_reviews":"you need harvard law degree to operate this thing it going back very soon","pred_label":""},{"clean_reviews":"as an alexa device it works just as well as any of the other products unfortunately it doesn go up from there the ability to play videos is very limited you can not play youtube and when you can play video the cropping of th ...
#   ```

# %%
import json
import pandas as pd

dfs = []  # Initialize an empty list to store DataFrame objects

for response in responses:
    # Clean the data by stripping the backticks
    json_data = response.text.strip("`")

    # Load the cleaned data
    data = json.loads(json_data)

    # Convert to DataFrame
    df_temp = pd.DataFrame(data)

    # Append the DataFrame to the list
    dfs.append(df_temp)

# Concatenate all DataFrames in the list into a single DataFrame
df_total = pd.concat(dfs, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0   we really love our echo dot we can get questio...           1
# 1    have now used for several months without problem           1
# 2   item no longer works after just 5 months of us...           0
# 3   works good however the price went down the wee...           1
# 4   easy to set up and does everything it poster d...           1
# ..                                                ...         ...
# 95  it is as if we are having conversation with an...           1
# 96  you need harvard law degree to operate this th...           0
# 97  as an alexa device it works just as well as an...           0
# 98                                          very good           1
# 99  it ok the speaker is pretty terrible google ho...           0
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 2929  We really love our Echo Dot, we can get questi...      1
# 436   Have now used for several months without problem.      1
# 350   Item no longer works after just 5 months of us...      0
# 493   Works good. However, the price went down the w...      1
# 3036  Easy to set up and does everything it’s a post...      1
# ...                                                 ...    ...
# 1899  It is as if we are having a conversation with ...      1
# 1225  You need a Harvard law degree to operate this ...      0
# 1104  As an Alexa device, it works just as well as a...      0
# 1406                                          Very good      1
# 668   It's ok. The speaker is pretty terrible. Googl...      0
#
#                                           clean_reviews  pred_label
# 2929  we really love our echo dot we can get questio...           1
# 436    have now used for several months without problem           1
# 350   item no longer works after just 5 months of us...           0
# 493   works good however the price went down the wee...           1
# 3036  easy to set up and does everything it poster d...           1
# ...                                                 ...         ...
# 1899  it is as if we are having conversation with an...           1
# 1225  you need harvard law degree to operate this th...           0
# 1104  as an alexa device it works just as well as an...           0
# 1406                                          very good           1
# 668   it ok the speaker is pretty terrible google ho...           0
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[49,  0],
#        [ 4, 47]])

# %% [markdown]
# ## Batching API Calls: ChatGPT (Few Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2515                             The volume is very low      0
# 2655  It works OK. This speaker quality is not much ...      1
# 900   It's got great sound and bass but it doesn't w...      0
# 2349  I don’t like that it goes into sleep mode afte...      0
# 2823  Nope. Still a lot to be improved. For most of ...      0
# ...                                                 ...    ...
# 1583                                 Fairly easy to use      1
# 1306  Can’t be used as a baby monitor which is why I...      0
# 1278  Great product EXCEPT there is no possible way ...      0
# 2878                    love it as I do all of my echos      1
# 2302                                            Awesome      1
#
#                                           clean_reviews pred_label
# 2515                             the volume is very low
# 2655  it works ok this speaker quality is not much b...
# 900   it got great sound and bass but it doesn work ...
# 2349  don like that it goes into sleep mode after 20...
# 2823  nope still lot to be improved for most of the ...
# ...                                                 ...        ...
# 1583                                 fairly easy to use
# 1306  can be used as baby monitor which is why had p...
# 1278  great product except there is no possible way ...
# 2878                      love it as do all of my echos
# 2302                                            awesome
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,train_sample,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  sample_json_data = train_sample[['clean_reviews','label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
  Examples of good Sentiment Analysis Classification are provided between separator ####.
  These examples are for your reference, not to be included in your final output.

  ```
  {json_data}
  ```
  ####
  {sample_json_data}
  ####
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
train_sample = train_set.sample(4)

batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count,train_sample))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"it works ok this speaker quality is not much better than my iphone would spend the extra money to get the full size echo which has great sound quality","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"don like that it goes into sleep mode after 20 30 minutes of inactivity shouldn have to wake up the fire tv to finish watching show","pred_label":""},{"clean_reviews":"nope still lot to be improved for most of the things we ask it says hmmmm dont know that","pred_label":""},{"clean_reviews":"love my echo dot the price paid during prime day was comparable to buying new digital clock with the bells and whistles but this does so much more can play music set alarms call friends play games set timers the list goes on and on definitely worth the money","pred_label":""},{"clean_reviews":"meh","pred_label":""},{"clean_reviews":"all the new amazon products have are great everything bought refurbished is complete garbage will never purchase amazon refurbished again total dissatisfaction","pred_label":""},{"clean_reviews":"love this replaced an old alarm clock in my bedroom with this love that it dims at night very responsive to commands","pred_label":""},{"clean_reviews":"it works perfect","pred_label":""},{"clean_reviews":"love it it is awesome","pred_label":""},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":""},{"clean_reviews":"was skeptical at first but 34 it 34 grows on you it looks good so far did however turn off the camera","pred_label":""},{"clean_reviews":"been debating on getting one but am happy did still more to explore thanks","pred_label":""},{"clean_reviews":"there was something wrong with the first one that no even the rep spoke with could fix the replacement was registered to someone else when the price of the dot went down to 39 99 same price as the refurbished ones bought brand spanking new one no problem with the new one","pred_label":""},{"clean_reviews":"the echo part works fine the hue hub is disaster it worked for few months and then nothing spent 2 hours on the phone with tech support one to have to send it in for repair am now trying to reconnect my lights what pain am having to reset each light bulb it can take up to 5 times to get it to reset have spent hours on this will say customer service was friendly and tried to be helpful stick with the echo and smart plugs for lamps","pred_label":""},{"clean_reviews":"love it and my family loves it also we use it all the time we also like playing the games that you can get on it too great for family game nights","pred_label":""},{"clean_reviews":"we like it very convenient","pred_label":""},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":""},{"clean_reviews":"the product sounded the same as the emoji speaker from five below m ...
#   ```
#   ####
#   [{"clean_reviews":"bought this for our son as his birthday present and he loves it often find him jamming to music in his room now he loves the options for the alarms and we have his weekday alarms set to repeat and he gets to sleep in on non school days","label":1},{"clean_reviews":"not connected to my phone playlist","label":0},{"clean_reviews":"when you think about it this really doesn do much play music answer stupid questions finally it was able to hook up to thermostat can see why price is dropping like rock","label":0},{"clean_reviews":"stopped working after 7 months the warranty was only good for 3 months would have assumed an amazon product sold on amazon would have had higher standards than guaranteeing that it would work for 3 whole months mean what is this product supposed to be piece of junk they offered my 15 discount if wanted to buy another one why would want to buy another one","label":0}]
#   ####
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"this thing woke me up in the middle of the night saying ready for setup it was already setup should be simple thing to check time before asking wife not happy","pred_label":""},{"clean_reviews":"this was an impulse buy and am super happy made the purchase love this so much immediately bought my parents one now we can video chat easily love all the features and how easy this is to use and set up","pred_label":""},{"clean_reviews":"ask it to play motown radio on pandora and it keeps asking if want to add salsa station motown isn close to salsa phonetically","pred_label":""},{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"have been through 4 shows now and all of them have been broken it has been anything from screens that lose lines of resolution to timers and reminders going off an hour late or reminders that trigger when trying to set other reminders don have these issues on my dot or my echo just on the show it would be nice if amazon could get there act together and actually fix this thing","pred_label":""},{"clean_reviews":"love being able to see information that alexa gives when notifications are turned on it lets you know when your order will be delivered and it also tells you what the order is you can use the echo screen to pull up details of your orders you can use the alexa skill to make calls from uhyour echo","pred_label":""},{"clean_reviews":"haven had it week and already it cannot connect to my network tried reconnecting manually and the echo never appears in the list of devices to connect it will be on it way back to amazon","pred_label":""},{"clean_reviews":"sure the echo is as cool as everyone says but won get to try this one even though have large covered porch the package was left on my top step on day forecast for 100 chance of rain and rain it did soaking the package not even going to open it and see how bad the damage is this order has been cursed from the beginning ordered as birthday gift and delivery was not made on scheduled day now get it and its rain soaked","pred_label":""},{"clean_reviews":"absolutely love my echo show it is awesome and works great with my ring video spotlight cams music on demand and so many more features that have yet to explore","pred_label":""},{"clean_reviews":"good","pred_label":""},{"clean_reviews":"love that you can use your cell phone to call echo or dot you can also use echo and dot as intercoms","pred_label":""},{"clean_reviews":"have had for just one week so far and can say it is blast to have","pred_label":""},{"clean_reviews":"didn order it","pred_label":""},{"clean_reviews":"liked it until on day after year it no longer worked would not power up and go past the firestick logo on tv bought second one will not buy third if this one doesn last longer","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"very amazing product great sound quality","pred_label":""},{"clean_reviews":"the echo dot 2nd generation smart speaker is very compound in size however it projects very good sound it also has port in which you can connect an external speaker for greater projection of sound also like it size because it not awkward and it doesn take up lot of space it works great with the alexa app also think the size is great for college students who live in dorm rooms with small limited spacing","pred_label":""},{"clean_reviews":"this device does not interact with my home filled with apple devices how disappointing","pred_label":""},{"clean_reviews":"alexa hardly came on","pred_label":""},{"clean_reviews":"works great can tell it was refurbished and set up in kids mode have 3 in my home and will be adding more love these things","pred_label":""},{"clean_reviews":"it don show nothing","pred_label": ...
#   ```
#   ####
#   [{"clean_reviews":"bought this for our son as his birthday present and he loves it often find him jamming to music in his room now he loves the options for the alarms and we have his weekday alarms set to repeat and he gets to sleep in on non school days","label":1},{"clean_reviews":"not connected to my phone playlist","label":0},{"clean_reviews":"when you think about it this really doesn do much play music answer stupid questions finally it was able to hook up to thermostat can see why price is dropping like rock","label":0},{"clean_reviews":"stopped working after 7 months the warranty was only good for 3 months would have assumed an amazon product sold on amazon would have had higher standards than guaranteeing that it would work for 3 whole months mean what is this product supposed to be piece of junk they offered my 15 discount if wanted to buy another one why would want to buy another one","label":0}]
#   ####

# %%
import json
import pandas as pd

# Initialize an empty list to store DataFrame objects
dfs = []

for response in responses:
    # Clean the data by stripping the backticks
    json_data = response.strip("`")

    # Load the cleaned data and convert to DataFrame
    data = json.loads(json_data)
    df_temp = pd.DataFrame(data)

    # Append the DataFrame to the list
    dfs.append(df_temp)

# Concatenate all DataFrames in the list into a single DataFrame
df_total = pd.concat(dfs, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0                              the volume is very low           0
# 1   it works ok this speaker quality is not much b...           0
# 2   it got great sound and bass but it doesn work ...           0
# 3   don like that it goes into sleep mode after 20...           0
# 4   nope still lot to be improved for most of the ...           0
# ..                                                ...         ...
# 95                                 fairly easy to use           1
# 96  can be used as baby monitor which is why had p...           0
# 97  great product except there is no possible way ...           0
# 98                      love it as do all of my echos           1
# 99                                            awesome           1
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 2515                             The volume is very low      0
# 2655  It works OK. This speaker quality is not much ...      1
# 900   It's got great sound and bass but it doesn't w...      0
# 2349  I don’t like that it goes into sleep mode afte...      0
# 2823  Nope. Still a lot to be improved. For most of ...      0
# ...                                                 ...    ...
# 1583                                 Fairly easy to use      1
# 1306  Can’t be used as a baby monitor which is why I...      0
# 1278  Great product EXCEPT there is no possible way ...      0
# 2878                    love it as I do all of my echos      1
# 2302                                            Awesome      1
#
#                                           clean_reviews  pred_label
# 2515                             the volume is very low           0
# 2655  it works ok this speaker quality is not much b...           0
# 900   it got great sound and bass but it doesn work ...           0
# 2349  don like that it goes into sleep mode after 20...           0
# 2823  nope still lot to be improved for most of the ...           0
# ...                                                 ...         ...
# 1583                                 fairly easy to use           1
# 1306  can be used as baby monitor which is why had p...           0
# 1278  great product except there is no possible way ...           0
# 2878                      love it as do all of my echos           1
# 2302                                            awesome           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[49  1]
#  [ 5 45]]
#
# Accuracy: 0.94
